# %%
## Cleaning the raw data for NYC TAXI FARE PREDICTION Project

# %%
import pandas as pd
import glob

# %%
files = glob.glob(r"D:\DATA\Project\8420\*.parquet")
files
# Out:
# ['D:\\DATA\\Project\\8420\\yellow_tripdata_2025-04.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-05.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-06.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-07.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-08.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-09.parquet']

# %%
ff = files
ff
# Out:
# ['D:\\DATA\\Project\\8420\\yellow_tripdata_2025-04.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-05.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-06.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-07.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-08.parquet',
#  'D:\\DATA\\Project\\8420\\yellow_tripdata_2025-09.parquet']

# %%
dfs = [pd.read_parquet(f) for f in ff]

combined = pd.concat(dfs, ignore_index=True)

# %%
combined.shape
# Out:
# (24609427, 20)

# %%
df = combined
#df = pd.read_csv(r"D:\DATA\Project\8420\Taxi_data.csv")

# %%
df.head(50)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2025-04-01 00:47:06   2025-04-01 01:13:25              1.0
# 1          2  2025-04-01 00:27:35   2025-04-01 00:38:19              2.0
# 2          2  2025-04-01 00:24:07   2025-04-01 00:35:12              1.0
# 3          1  2025-04-01 00:56:30   2025-04-01 01:00:49              2.0
# 4          2  2025-04-01 00:00:17   2025-04-01 00:16:19              1.0
# 5          7  2025-04-01 00:39:00   2025-04-01 00:39:00              1.0
# 6          2  2025-04-01 00:54:37   2025-04-01 01:14:10              1.0
# 7          2  2025-04-01 00:11:13   2025-04-01 00:28:08              2.0
# 8          1  2025-04-01 00:33:16   2025-04-01 00:34:46              1.0
# 9          2  2025-04-01 00:48:56   2025-04-01 01:18:35              1.0
# 10         2  2025-04-01 00:55:44   2025-04-01 01:01:37              1.0
# 11         2  2025-04-01 00:15:21   2025-04-01 00:28:13              3.0
# 12         2  2025-04-01 00:51:06   2025-04-01 01:05:28              1.0
# 13         1  2025-04-01 00:13:35   2025-04-01 00:34:32              1.0
# 14         1  2025-04-01 00:36:37   2025-04-01 01:05:35              1.0
# 15         2  2025-04-01 00:11:49   2025-04-01 00:26:46              1.0
# 16         2  2025-04-01 00:53:39   2025-04-01 01:25:47              2.0
# 17         2  2025-04-01 00:12:10   2025-04-01 00:34:28              1.0
# 18         2  2025-04-01 00:05:06   2025-04-01 00:20:30              1.0
# 19         2  2025-04-01 00:28:26   2025-04-01 00:44:48              1.0
# 20         2  2025-04-01 00:54:34   2025-04-01 00:59:13              1.0
# 21         2  2025-04-01 00:38:01   2025-04-01 00:40:26              1.0
# 22         1  2025-04-01 00:52:29   2025-04-01 01:04:26              1.0
# 23         2  2025-04-01 00:36:34   2025-04-01 00:55:45              1.0
# 24         1  2025-04-01 00:09:20   2025-04-01 00:37:56              1.0
# 25         1  2025-04-01 00:48:22   2025-04-01 01:10:53              1.0
# 26         2  2025-04-01 00:35:18   2025-04-01 00:41:23              1.0
# 27         2  2025-04-01 00:45:01   2025-04-01 00:47:17              1.0
# 28         2  2025-04-01 00:07:18   2025-04-01 00:30:29              2.0
# 29         2  2025-04-01 00:11:23   2025-04-01 00:19:43              1.0
# 30         2  2025-04-01 00:29:20   2025-04-01 00:46:18              1.0
# 31         2  2025-04-01 00:04:27   2025-04-01 00:06:48              1.0
# 32         2  2025-04-01 00:35:44   2025-04-01 00:41:44              1.0
# 33         2  2025-04-01 00:49:40   2025-04-01 01:30:10              1.0
# 34         2  2025-04-01 00:33:30   2025-04-01 00:33:34              1.0
# 35         2  2025-04-01 00:33:52   2025-04-01 00:38:48              1.0
# 36         2  2025-04-01 00:16:08   2025-04-01 00:25:37              1.0
# 37         2  2025-04-01 00:50:18   2025-04-01 00:55:42              1.0
# 38         2  2025-04-01 00:03:16   2025-04-01 00:15:33              1.0
# 39         1  2025-04-01 00:38:44   2025-04-01 00:45:32              1.0
# 40         2  2025-04-01 00:09:25   2025-04-01 00:17:24              2.0
# 41         1  2025-04-01 00:03:02   2025-04-01 00:38:47              0.0
# 42         2  2025-04-01 00:39:35   2025-04-01 00:48:32              1.0
# 43         2  2025-04-01 00:02:36   2025-04-01 00:12:43              2.0
# 44         1  2025-04-01 00:02:36   2025-04-01 00:17:12              1.0
# 45         1  2025-04-01 00:57:33   2025-04-01 01:14:00              1.0
# 46         7  2025-04-01 00:25:00   2025-04-01 00:25:00              1.0
# 47         2  2025-04-01 00:20:54   2025-04-01 01:06:42              1.0
# 48         2  2025-04-01 00:20:54   2025-04-01 01:06:42              1.0
# 49         1  2025-04-01 00:20:07   2025-04-01 00:44:01              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            9.50         1.0                  N           138           230
# 1            3.77         1.0                  N           138            92
# 2            5.41         1.0                  N           132           130
# 3            0.60         1.0                  N            79             4
# 4            0.43         1.0                  N           161           229
# 5            0.95         1.0                  N           233           164
# 6            8.94         1.0                  N           138           140
# 7            8.79         1.0                  N           138           116
# 8            0.50         1.0                  N           239           238
# 9           16.62         2.0                  N           132           162
# 10           0.94         1.0                  N           144           125
# 11           2.40         1.0                  N           142           151
# 12           3.19         1.0                  N           162             7
# 13           8.70         1.0                  N           138           236
# 14           0.00         1.0                  N            68            17
# 15           3.06         1.0                  N           114           229
# 16          18.96         2.0                  N           132            41
# 17          11.13         1.0                  N           138           125
# 18           3.22         1.0                  N            68           229
# 19           2.86         1.0                  N           107            87
# 20           1.09         1.0                  N           231           114
# 21           1.05         1.0                  N           237           162
# 22           5.10         1.0                  N           132           130
# 23           6.52         1.0                  N           132           134
# 24          11.00         1.0                  N           138           249
# 25           4.60         1.0                  N           249           100
# 26           1.69         1.0                  N           239           151
# 27           0.61         1.0                  N           151           238
# 28           8.96         1.0                  N           132           196
# 29           2.37         1.0                  N           229           114
# 30           4.83         1.0                  N           234             7
# 31           0.49         1.0                  N           140           140
# 32           1.00         1.0                  N           161           170
# 33           8.03         1.0                  N           249           129
# 34           0.00         1.0                  N            68            68
# 35           1.23         1.0                  N            68            48
# 36           1.94         1.0                  N           130           215
# 37           0.91         1.0                  N            76            76
# 38           2.64         1.0                  N           100           142
# 39           0.90         1.0                  N           114            79
# 40           3.52         1.0                  N           138           179
# 41          18.20         2.0                  N           132           230
# 42           1.89         1.0                  N           186            50
# 43           1.87         1.0                  N           114           209
# 44           6.50         1.0                  N           264           264
# 45          11.10         1.0                  N           138           233
# 46           2.04         1.0                  N           239           230
# 47          14.98         1.0                  N           238            61
# 48          14.98         1.0                  N           238            61
# 49          10.50         1.0                  N            70           158
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1         38.7  11.00      0.5       11.65          6.94
# 1              1         17.0   6.00      0.5        4.90          0.00
# 2              1         22.6   1.00      0.5        5.37          0.00
# 3              1          6.5   4.25      0.5        2.45          0.00
# 4              2          4.4   1.00      0.5        0.00          0.00
# 5              1          5.8   0.00      0.5        0.00          0.00
# 6              1         35.9   6.00      0.5       10.57          6.94
# 7              1         35.2   6.00      0.5        5.14          6.94
# 8              1          4.4   3.50      0.5        1.85          0.00
# 9              1         70.0   0.00      0.5       16.34          6.94
# 10             1          7.9   1.00      0.5        0.00          0.00
# 11             1         14.2   1.00      0.5        3.99          0.00
# 12             2         17.0   1.00      0.5        0.00          0.00
# 13             1         33.8  10.25      0.5       10.50          6.94
# 14             1         29.5   0.00      0.5        0.00          0.00
# 15             1         17.0   1.00      0.5        2.00          0.00
# 16             1         70.0   0.00      0.5       15.69          6.94
# 17             1         44.3   6.00      0.5       11.36          0.00
# 18             1         17.7   1.00      0.5        4.69          0.00
# 19             1         17.7   1.00      0.5        4.69          0.00
# 20             1          7.2   1.00      0.5        2.59          0.00
# 21             2          6.5   1.00      0.5        0.00          0.00
# 22             1         21.2   2.75      0.5        5.10          0.00
# 23             1         30.3   1.00      0.5        6.56          0.00
# 24             2         44.3  11.00      0.5        0.00          6.94
# 25             1         22.6   4.25      0.5        5.65          0.00
# 26             1          9.3   1.00      0.5        1.00          0.00
# 27             1          5.1   1.00      0.5        0.00          0.00
# 28             1         36.6   1.00      0.5        9.78          0.00
# 29             1         12.1   1.00      0.5        2.00          0.00
# 30             1         23.3   1.00      0.5        0.00          0.00
# 31             2          5.1   1.00      0.5        0.00          0.00
# 32             1          7.9   1.00      0.5        1.00          0.00
# 33             1         41.5   1.00      0.5        9.45          0.00
# 34             2          3.0   1.00      0.5        0.00          0.00
# 35             1          7.9   1.00      0.5        2.00          0.00
# 36             2         11.4   1.00      0.5        0.00          0.00
# 37             2          7.2   1.00      0.5        0.00          0.00
# 38             1         14.2   1.00      0.5        3.99          0.00
# 39             1          8.6   4.25      0.5        2.85          0.00
# 40             1         15.6   6.00      0.5        4.62          0.00
# 41             1         70.0   5.00      0.5        5.00          6.94
# 42             1         11.4   1.00      0.5        3.43          0.00
# 43             1         12.1   1.00      0.5        3.57          0.00
# 44             1         26.8   1.00      0.5        5.85          0.00
# 45             1         42.9  11.00      0.5        8.00          6.94
# 46             2         12.1   0.00      0.5        0.00          0.00
# 47             4        -65.3  -1.00     -0.5        0.00         -6.94
# 48             4         65.3   1.00      0.5        0.00          6.94
# 49             1         42.9  11.00      0.5       11.05          0.00
#
#     improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                     1.0         69.79                   2.5         1.75
# 1                     1.0         31.15                   0.0         1.75
# 2                     1.0         32.22                   0.0         1.75
# 3                     1.0         14.70                   2.5         0.00
# 4                     1.0         10.15                   2.5         0.00
# 5                     1.0         11.55                   2.5         0.00
# 6                     1.0         65.16                   2.5         1.75
# 7                     1.0         56.53                   0.0         1.75
# 8                     1.0         11.25                   2.5         0.00
# 9                     1.0         99.78                   2.5         1.75
# 10                    1.0         13.65                   2.5         0.00
# 11                    1.0         23.94                   2.5         0.00
# 12                    1.0         22.75                   2.5         0.00
# 13                    1.0         62.99                   2.5         1.75
# 14                    1.0         31.00                   0.0         0.00
# 15                    1.0         24.75                   2.5         0.00
# 16                    1.0         95.88                   0.0         1.75
# 17                    1.0         68.16                   2.5         1.75
# 18                    1.0         28.14                   2.5         0.00
# 19                    1.0         28.14                   2.5         0.00
# 20                    1.0         15.54                   2.5         0.00
# 21                    1.0         12.25                   2.5         0.00
# 22                    1.0         30.55                   0.0         1.75
# 23                    1.0         41.11                   0.0         1.75
# 24                    1.0         63.74                   2.5         1.75
# 25                    1.0         34.00                   2.5         0.00
# 26                    1.0         15.30                   2.5         0.00
# 27                    1.0          7.60                   0.0         0.00
# 28                    1.0         50.63                   0.0         1.75
# 29                    1.0         19.85                   2.5         0.00
# 30                    1.0         29.05                   2.5         0.00
# 31                    1.0         10.10                   2.5         0.00
# 32                    1.0         14.65                   2.5         0.00
# 33                    1.0         56.70                   2.5         0.00
# 34                    1.0          8.75                   2.5         0.00
# 35                    1.0         15.65                   2.5         0.00
# 36                    1.0         13.90                   0.0         0.00
# 37                    1.0          9.70                   0.0         0.00
# 38                    1.0         23.94                   2.5         0.00
# 39                    1.0         17.20                   2.5         0.00
# 40                    1.0         29.47                   0.0         1.75
# 41                    1.0         88.44                   2.5         1.75
# 42                    1.0         20.58                   2.5         0.00
# 43                    1.0         21.42                   2.5         0.00
# 44                    1.0         35.15                   0.0         0.00
# 45                    1.0         70.34                   2.5         1.75
# 46                    1.0         17.85                   2.5         0.00
# 47                   -1.0        -77.24                  -2.5         0.00
# 48                    1.0         77.24                   2.5         0.00
# 49                    1.0         66.45                   2.5         1.75
#
#     cbd_congestion_fee
# 0                 0.75
# 1                 0.00
# 2                 0.00
# 3                 0.75
# 4                 0.75
# 5                 0.75
# 6                 0.00
# 7                 0.00
# 8                 0.00
# 9                 0.75
# 10                0.75
# 11                0.75
# 12                0.75
# 13                0.00
# 14                0.00
# 15                0.75
# 16                0.00
# 17                0.75
# 18                0.75
# 19                0.75
# 20                0.75
# 21                0.75
# 22                0.00
# 23                0.00
# 24                0.75
# 25                0.75
# 26                0.00
# 27                0.00
# 28                0.00
# 29                0.75
# 30                0.75
# 31                0.00
# 32                0.75
# 33                0.75
# 34                0.75
# 35                0.75
# 36                0.00
# 37                0.00
# 38                0.75
# 39                0.75
# 40                0.00
# 41                0.75
# 42                0.75
# 43                0.75
# 44                0.00
# 45                0.75
# 46                0.75
# 47                0.00
# 48                0.00
# 49                0.75

# %%
print(df['tpep_pickup_datetime'].dtype)
# Out:
# datetime64[us]

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'], errors='coerce')
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'], errors='coerce')

# %%
#Confirming if there are trips that with durations being more than a day
df['trip_duration_min'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
df[(df['trip_duration_min']/60) > 24]
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 456384           2  2025-04-05 01:56:07   2025-04-08 17:12:44
# 456860           2  2025-04-05 01:02:35   2025-04-06 12:32:40
# 679066           2  2025-04-07 10:09:19   2025-04-08 14:51:19
# 679541           2  2025-04-07 10:19:28   2025-04-08 10:26:55
# 792585           2  2025-04-08 12:10:32   2025-04-10 15:04:17
# ...            ...                  ...                   ...
# 23822318         1  2025-09-09 19:45:26   2025-09-16 16:52:29
# 24009468         1  2025-09-14 00:58:11   2025-09-15 13:55:57
# 24106492         6  2025-09-16 20:08:00   2025-09-18 00:36:48
# 24185885         2  2025-09-19 01:06:49   2025-09-20 19:06:14
# 24191027         1  2025-09-19 08:35:19   2025-09-22 09:34:56
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 456384                1.0           0.39         1.0                  N
# 456860                1.0           1.97         5.0                  N
# 679066                1.0           0.00         1.0                  N
# 679541                1.0           0.00         1.0                  N
# 792585                1.0           1.80         1.0                  N
# ...                   ...            ...         ...                ...
# 23822318              NaN           0.90         NaN               None
# 24009468              NaN           4.50         NaN               None
# 24106492              NaN           7.33         NaN               None
# 24185885              NaN           0.00         NaN               None
# 24191027              NaN           3.30         NaN               None
#
#           PULocationID  DOLocationID  payment_type  ...  extra  mta_tax  \
# 456384             107            48             2  ...    1.0      0.5
# 456860              37            37             2  ...    0.0      0.5
# 679066             207           146             2  ...    0.0      0.5
# 679541             207             7             2  ...    0.0      0.5
# 792585              10           215             2  ...    0.0      0.5
# ...                ...           ...           ...  ...    ...      ...
# 23822318           236           262             0  ...    0.0      0.5
# 24009468            82           140             0  ...    0.0      0.5
# 24106492            75           241             0  ...    0.0      0.5
# 24185885           150           150             0  ...    0.0      0.5
# 24191027           164            88             0  ...    0.0      0.5
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 456384          0.00           0.0                    1.0         10.85
# 456860          0.00           0.0                    1.0         19.49
# 679066          0.00           0.0                    1.0          4.50
# 679541          0.00           0.0                    1.0          4.50
# 792585          0.00           0.0                    1.0         19.90
# ...              ...           ...                    ...           ...
# 23822318        0.00           0.0                    1.0         13.22
# 24009468        0.00           0.0                    1.0         30.70
# 24106492        0.00           0.0                    0.3         30.24
# 24185885        0.43           0.0                    1.0         12.34
# 24191027        0.00           0.0                    1.0         30.46
#
#           congestion_surcharge  Airport_fee  cbd_congestion_fee  \
# 456384                     2.5          0.0                0.75
# 456860                     0.0          0.0                0.00
# 679066                     0.0          0.0                0.00
# 679541                     0.0          0.0                0.00
# 792585                     0.0          0.0                0.00
# ...                        ...          ...                 ...
# 23822318                   NaN          NaN                0.00
# 24009468                   NaN          NaN                0.00
# 24106492                   NaN          NaN                0.00
# 24185885                   NaN          NaN                0.00
# 24191027                   NaN          NaN                0.75
#
#           trip_duration_min
# 456384          5236.616667
# 456860          2130.083333
# 679066          1722.000000
# 679541          1447.450000
# 792585          3053.750000
# ...                     ...
# 23822318        9907.050000
# 24009468        2217.766667
# 24106492        1708.800000
# 24185885        2519.416667
# 24191027        4379.616667
#
# [184 rows x 21 columns]

# %%
#Drop rows where passenger count is NaN
df = df.dropna(subset=['passenger_count'])

# %%
#Keeping row where passenger counts are not zero
df = df[df['passenger_count'] > 0]

# %%
print(df['PULocationID'].dtype)
# Out:
# int32

# %%
#Drop Rows where drop of and pick up locations are outside of New York or not known
df = df[~df['PULocationID'].isin([264,265])]
df = df[~df['DOLocationID'].isin([264,265])]

# %%
df.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int32
# DOLocationID                      int32
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# cbd_congestion_fee              float64
# trip_duration_min               float64
# dtype: object

# %%
#Removing rows based on their payment type
#0 - rare and mostly a subscription or special fare; doesnt seem to be there in the dataset
#3 - Its free trips and as such generates no fare
#4 - disputed; so could be incorrect or reversed
#5 - unknown; not real case
#6 - voided trips; generates no fare
df = df[~df['payment_type'].isin([0,3,4,5,6])]

# %%
df['payment_type'].unique()
# Out:
# array([1, 2])

# %%
df.sort_values(by='fare_amount', ascending=True).head()
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 2928014          2  2025-04-28 10:36:21   2025-04-28 10:36:50
# 16932547         2  2025-08-02 18:07:49   2025-08-02 18:08:14
# 9843121          2  2025-06-12 21:31:58   2025-06-13 18:35:49
# 10141725         2  2025-06-15 22:25:47   2025-06-15 22:25:55
# 2119962          2  2025-04-20 21:18:34   2025-04-20 21:18:39
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 2928014               1.0         101.65         1.0                  N
# 16932547              3.0           0.00         5.0                  N
# 9843121               1.0           9.37         1.0                  N
# 10141725              1.0           0.00         5.0                  N
# 2119962               1.0           0.00         5.0                  N
#
#           PULocationID  DOLocationID  payment_type  ...  extra  mta_tax  \
# 2928014            193           193             2  ...  -3.25     -0.5
# 16932547           132           132             2  ...   0.00      0.0
# 9843121            138           193             2  ...  -6.00     -0.5
# 10141725           226           226             2  ...   0.00      0.0
# 2119962            132           132             2  ...   0.00      0.0
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 2928014         0.00          0.00                   -1.0      -1052.15
# 16932547        0.00          0.00                   -1.0      -1000.00
# 9843121         0.00         -6.94                   -1.0       -917.34
# 10141725        0.01          0.00                   -1.0       -900.99
# 2119962         0.00          0.00                   -1.0       -802.75
#
#           congestion_surcharge  Airport_fee  cbd_congestion_fee  \
# 2928014                    0.0         0.00                0.00
# 16932547                   0.0         0.00                0.00
# 9843121                    0.0        -1.75               -0.75
# 10141725                   0.0         0.00                0.00
# 2119962                    0.0        -1.75                0.00
#
#           trip_duration_min
# 2928014            0.483333
# 16932547           0.416667
# 9843121         1263.850000
# 10141725           0.133333
# 2119962            0.083333
#
# [5 rows x 21 columns]

# %%
#Removing payment type column as it will only contain rows that are paid in cash or by card.
df = df.drop(columns=['payment_type'])

# %%
#Removing store_and_fwd_flag as its meant for audit purpose and doesnt really effect fare prices:
df = df.drop(columns=['store_and_fwd_flag'])

# %%
#Removing rows where the ratecodeID  is 99 or just NaN to prevent data quality issues.
df = df.dropna(subset=['RatecodeID'])
df = df[~df['RatecodeID'].isin([99])]
df[df['RatecodeID']==99].count()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# Airport_fee              0
# cbd_congestion_fee       0
# trip_duration_min        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee',
#        'trip_duration_min'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# Airport_fee              0
# cbd_congestion_fee       0
# trip_duration_min        0
# dtype: int64

# %%
#Inspecting fare prices
pd.set_option('display.float_format', '{:,.2f}'.format) #Remvoing the exponent format
df['fare_amount'].describe()
# Out:
# count   17,037,699.00
# mean            19.13
# std            112.64
# min         -1,047.40
# 25%              9.30
# 50%             13.50
# 75%             21.20
# max        325,478.05
# Name: fare_amount, dtype: float64

# %%
#There are some extreme outliers......
#To fix this, a fare range will be set from the base fare of $3 to a max of $500
#Why a base of $3? According to NYC.gov, it is the initial charge for a trip.
#Why a max of $500? It is a generous limit but should cover airport, toll and congestion prices

df = df[(df['fare_amount'] >= 3.00) & (df['fare_amount'] <= 500)]

# %%
#Checking
df['fare_amount'].describe()
# Out:
# count   16,926,926.00
# mean            19.36
# std             17.36
# min              3.00
# 25%              9.30
# 50%             13.50
# 75%             21.20
# max            500.00
# Name: fare_amount, dtype: float64

# %%
df.shape
# Out:
# (16926926, 19)

# %%
df[(df['trip_duration_min']/60) > 24]
#These trips are not realistic as it spans more than a day and as such will be removed. Likely caused by some error, time zone anomalies or just corrupted.
df = df[(df['trip_duration_min']/60) <= 24]
#Ensuring there are no negative or 0 time trips
df = df[df['trip_duration_min'] >0]

# %%
#We can remove "improvement_surcharge" and "mta_tax" seem to be fixed attributes or have very little deviation and as such can be removed.
df = df.drop(columns=['mta_tax', 'improvement_surcharge'])

# %%
#"Tip_amount" doesnt really dictate the fare so its not needed and "total_amount" can cause a data leak.
df = df.drop(columns=['tip_amount', 'total_amount'])

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'fare_amount', 'extra', 'tolls_amount',
#        'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee',
#        'trip_duration_min'],
#       dtype='object')

# %%
#Since all trips now occur within a single day, we only need one column for the day of the week and one column for the month, based on the pickup time.
#Additionally, a "time of day" category (Morning, Afternoon, Evening and Night) will be created using the pickup time, as the start time has a larger impact on fare than the drop-off time.

# %%
df['day_of_week'] = df['tpep_pickup_datetime'].dt.day_name()
df['month'] = df['tpep_pickup_datetime'].dt.month_name()
df['year'] = df['tpep_pickup_datetime'].dt.year
df['pickup_hour'] = df['tpep_pickup_datetime'].dt.hour
df['dropoff_hour'] = df['tpep_dropoff_datetime'].dt.hour

# %%
def time_of_day(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

df['time_of_day'] = df['pickup_hour'].apply(time_of_day)

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'fare_amount', 'extra', 'tolls_amount',
#        'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee',
#        'trip_duration_min', 'day_of_week', 'month', 'year', 'pickup_hour',
#        'dropoff_hour', 'time_of_day'],
#       dtype='object')

# %%
df['month'].unique()
# Out:
# array(['April', 'March', 'May', 'January', 'June', 'July', 'August',
#        'September', 'October'], dtype=object)

# %%
#Since temporal attributes are created there is no need for the 'tpep_pickup_datetime'and 'tpep_dropoff_datetime' attributes
df = df.drop(columns=['tpep_pickup_datetime', 'tpep_dropoff_datetime'])
df.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0         1             1.00           9.50        1.00           138
# 1         2             2.00           3.77        1.00           138
# 2         2             1.00           5.41        1.00           132
# 3         1             2.00           0.60        1.00            79
# 4         2             1.00           0.43        1.00           161
#
#    DOLocationID  fare_amount  extra  tolls_amount  congestion_surcharge  \
# 0           230        38.70  11.00          6.94                  2.50
# 1            92        17.00   6.00          0.00                  0.00
# 2           130        22.60   1.00          0.00                  0.00
# 3             4         6.50   4.25          0.00                  2.50
# 4           229         4.40   1.00          0.00                  2.50
#
#    Airport_fee  cbd_congestion_fee  trip_duration_min day_of_week  month  \
# 0         1.75                0.75              26.32     Tuesday  April
# 1         1.75                0.00              10.73     Tuesday  April
# 2         1.75                0.00              11.08     Tuesday  April
# 3         0.00                0.75               4.32     Tuesday  April
# 4         0.00                0.75              16.03     Tuesday  April
#
#    year  pickup_hour  dropoff_hour time_of_day
# 0  2025            0             1       Night
# 1  2025            0             0       Night
# 2  2025            0             0       Night
# 3  2025            0             1       Night
# 4  2025            0             0       Night

# %%
tf = pd.read_csv(r"D:\DATA\Project\8420\taxi_zone_lookup.csv")

# %%
tf.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
#Focus will be on only borough as it is broad and simple to work with, zone is alot more granular and could be useful for complex models. For the time being focus will be on boroughs along with EWR.
tf2 = tf[['LocationID', 'Borough']]
tf2.head()
# Out:
#    LocationID        Borough
# 0           1            EWR
# 1           2         Queens
# 2           3          Bronx
# 3           4      Manhattan
# 4           5  Staten Island

# %%
df['PU_Borough'] = df['PULocationID'].map(tf2.set_index('LocationID')['Borough'])
df['DO_Borough'] = df['DOLocationID'].map(tf2.set_index('LocationID')['Borough'])

# %%
df.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0         1             1.00           9.50        1.00           138
# 1         2             2.00           3.77        1.00           138
# 2         2             1.00           5.41        1.00           132
# 3         1             2.00           0.60        1.00            79
# 4         2             1.00           0.43        1.00           161
#
#    DOLocationID  fare_amount  extra  tolls_amount  congestion_surcharge  ...  \
# 0           230        38.70  11.00          6.94                  2.50  ...
# 1            92        17.00   6.00          0.00                  0.00  ...
# 2           130        22.60   1.00          0.00                  0.00  ...
# 3             4         6.50   4.25          0.00                  2.50  ...
# 4           229         4.40   1.00          0.00                  2.50  ...
#
#    cbd_congestion_fee  trip_duration_min  day_of_week  month  year  \
# 0                0.75              26.32      Tuesday  April  2025
# 1                0.00              10.73      Tuesday  April  2025
# 2                0.00              11.08      Tuesday  April  2025
# 3                0.75               4.32      Tuesday  April  2025
# 4                0.75              16.03      Tuesday  April  2025
#
#    pickup_hour  dropoff_hour  time_of_day PU_Borough DO_Borough
# 0            0             1        Night     Queens  Manhattan
# 1            0             0        Night     Queens     Queens
# 2            0             0        Night     Queens     Queens
# 3            0             1        Night  Manhattan  Manhattan
# 4            0             0        Night  Manhattan  Manhattan
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns=['PULocationID', 'DOLocationID'])
df.columns
# Out:
# Index(['VendorID', 'passenger_count', 'trip_distance', 'RatecodeID',
#        'fare_amount', 'extra', 'tolls_amount', 'congestion_surcharge',
#        'Airport_fee', 'cbd_congestion_fee', 'trip_duration_min', 'day_of_week',
#        'month', 'year', 'pickup_hour', 'dropoff_hour', 'time_of_day',
#        'PU_Borough', 'DO_Borough'],
#       dtype='object')

# %%
df.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  fare_amount  extra  \
# 0         1             1.00           9.50        1.00        38.70  11.00
# 1         2             2.00           3.77        1.00        17.00   6.00
# 2         2             1.00           5.41        1.00        22.60   1.00
# 3         1             2.00           0.60        1.00         6.50   4.25
# 4         2             1.00           0.43        1.00         4.40   1.00
#
#    tolls_amount  congestion_surcharge  Airport_fee  cbd_congestion_fee  \
# 0          6.94                  2.50         1.75                0.75
# 1          0.00                  0.00         1.75                0.00
# 2          0.00                  0.00         1.75                0.00
# 3          0.00                  2.50         0.00                0.75
# 4          0.00                  2.50         0.00                0.75
#
#    trip_duration_min day_of_week  month  year  pickup_hour  dropoff_hour  \
# 0              26.32     Tuesday  April  2025            0             1
# 1              10.73     Tuesday  April  2025            0             0
# 2              11.08     Tuesday  April  2025            0             0
# 3               4.32     Tuesday  April  2025            0             1
# 4              16.03     Tuesday  April  2025            0             0
#
#   time_of_day PU_Borough DO_Borough
# 0       Night     Queens  Manhattan
# 1       Night     Queens     Queens
# 2       Night     Queens     Queens
# 3       Night  Manhattan  Manhattan
# 4       Night  Manhattan  Manhattan

# %%
##Some descriptive stats of numerical variable to find outliers
num = df.select_dtypes(include = ['int64','float64']).columns
df[num].describe()
# Out:
#        passenger_count  trip_distance    RatecodeID   fare_amount  \
# count    16,608,071.00  16,608,071.00 16,608,071.00 16,608,071.00
# mean              1.31           3.29          1.09         19.42
# std               0.73          18.54          0.47         17.42
# min               1.00           0.00          1.00          3.00
# 25%               1.00           1.00          1.00          9.30
# 50%               1.00           1.70          1.00         13.50
# 75%               1.00           3.20          1.00         21.20
# max               9.00      48,199.11          6.00        500.00
#
#               extra  tolls_amount  congestion_surcharge   Airport_fee  \
# count 16,608,071.00 16,608,071.00         16,608,071.00 16,608,071.00
# mean           1.64          0.56                  2.34          0.16
# std            1.93          2.08                  0.61          0.50
# min          -17.39          0.00                  0.00          0.00
# 25%            0.00          0.00                  2.50          0.00
# 50%            1.00          0.00                  2.50          0.00
# 75%            2.50          0.00                  2.50          0.00
# max           38.61        134.06                  2.50          1.75
#
#        cbd_congestion_fee  trip_duration_min
# count       16,608,071.00      16,608,071.00
# mean                 0.58              16.72
# std                  0.32              28.42
# min                 -0.75               0.02
# 25%                  0.75               7.60
# 50%                  0.75              12.50
# 75%                  0.75              20.30
# max                  0.75           1,439.98

# %%
#Concerns:
#"extra" & "cbd_congestion_fee" have negative values
#"trip_distance" has 0 distance trips and a max trip of 48,199.11 which doesnt seem right....
#Even after removing trips with a duration of more than 24 hour, there are some trips that take a whole day

#To prevent issues, these outliers will be removed .....

#Distance
df = df[(df['trip_distance'] > 0) & (df['trip_distance'] <= 100)]

#Duration
df = df[(df['trip_duration_min'] >= 5) & (df['trip_duration_min'] <= 100)]

#These limits are alot more realistic and a bit too generous but should pose no problems.

#"extra" & "cbd_congestion_fee" we can replace with flags instead. The other raw fees can also be converted to flgs to prevent data leak.

# Flag for airport trips
df['is_airport_trip'] = (df['Airport_fee'] > 0).astype(int)

# Flag for CBD congestion
df['is_cbd_congestion'] = (df['cbd_congestion_fee'] > 0).astype(int)

# Flag for extra charges
df['has_extra'] = (df['extra'] > 0).astype(int)

# Flag for tolls
df['has_toll'] = (df['tolls_amount'] > 0).astype(int)

# Flag for congestion surcharge
df['has_congestion_surcharge'] = (df['congestion_surcharge'] > 0).astype(int)

# %%
#Removing the raw fee columns
df = df.drop(columns=['Airport_fee', 'cbd_congestion_fee', 'extra', 'tolls_amount', 'congestion_surcharge'])

# %%
df.shape
# Out:
# (14715034, 19)

# %%
#Checking...
num = df.select_dtypes(include = ['int64','float64']).columns
df[num].describe()
# Out:
#        passenger_count  trip_distance    RatecodeID   fare_amount  \
# count    14,715,034.00  14,715,034.00 14,715,034.00 14,715,034.00
# mean              1.32           3.61          1.07         20.64
# std               0.73           4.40          0.38         16.90
# min               1.00           0.01          1.00          3.00
# 25%               1.00           1.20          1.00         10.00
# 50%               1.00           1.90          1.00         14.20
# 75%               1.00           3.58          1.00         22.60
# max               9.00          93.60          6.00        500.00
#
#        trip_duration_min  is_airport_trip  is_cbd_congestion     has_extra  \
# count      14,715,034.00    14,715,034.00      14,715,034.00 14,715,034.00
# mean               17.79             0.10               0.79          0.60
# std                13.02             0.30               0.40          0.49
# min                 5.00             0.00               0.00          0.00
# 25%                 9.12             0.00               1.00          0.00
# 50%                13.82             0.00               1.00          1.00
# 75%                21.63             0.00               1.00          1.00
# max               100.00             1.00               1.00          1.00
#
#            has_toll  has_congestion_surcharge
# count 14,715,034.00             14,715,034.00
# mean           0.08                      0.94
# std            0.28                      0.24
# min            0.00                      0.00
# 25%            0.00                      1.00
# 50%            0.00                      1.00
# 75%            0.00                      1.00
# max            1.00                      1.00

# %%
#This seems alot more realistic and is in a perfect state for further EDA and modeling.

# %%
#Rearranging columns
columnn = 'fare_amount'

order = [c for c in df.columns if c != columnn]+ [columnn]

df = df[order]
df.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  trip_duration_min  \
# 0         1             1.00           9.50        1.00              26.32
# 1         2             2.00           3.77        1.00              10.73
# 2         2             1.00           5.41        1.00              11.08
# 4         2             1.00           0.43        1.00              16.03
# 6         2             1.00           8.94        1.00              19.55
#
#   day_of_week  month  year  pickup_hour  dropoff_hour time_of_day PU_Borough  \
# 0     Tuesday  April  2025            0             1       Night     Queens
# 1     Tuesday  April  2025            0             0       Night     Queens
# 2     Tuesday  April  2025            0             0       Night     Queens
# 4     Tuesday  April  2025            0             0       Night  Manhattan
# 6     Tuesday  April  2025            0             1       Night     Queens
#
#   DO_Borough  is_airport_trip  is_cbd_congestion  has_extra  has_toll  \
# 0  Manhattan                1                  1          1         1
# 1     Queens                1                  0          1         0
# 2     Queens                1                  0          1         0
# 4  Manhattan                0                  1          1         0
# 6  Manhattan                1                  0          1         1
#
#    has_congestion_surcharge  fare_amount
# 0                         1        38.70
# 1                         0        17.00
# 2                         0        22.60
# 4                         1         4.40
# 6                         1        35.90

# %%
df.columns
# Out:
# Index(['VendorID', 'passenger_count', 'trip_distance', 'RatecodeID',
#        'trip_duration_min', 'day_of_week', 'month', 'year', 'pickup_hour',
#        'dropoff_hour', 'time_of_day', 'PU_Borough', 'DO_Borough',
#        'is_airport_trip', 'is_cbd_congestion', 'has_extra', 'has_toll',
#        'has_congestion_surcharge', 'fare_amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (14715034, 19)

# %%
#Saving the file
df.to_csv(r"D:\DATA\Project\8420\Taxi_data_clean.csv", index= False )

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
